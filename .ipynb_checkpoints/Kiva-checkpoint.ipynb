# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
kiva = pd.read_csv("Kiva Loan.csv")

# %%
kiva.head(2)
# Out:
#    id           Funded Date  Funded Amount Country Country Code  \
# 0  84  2005-03-31T06:27:55Z            500  Uganda           UG
# 1  85  2005-03-31T06:27:55Z            500  Uganda           UG
#
#   Local Currency  Loan Amount             Paid Date  Paid Amount  \
# 0            NaN          500  2005-12-13T12:00:40Z        500.0
# 1            NaN          500  2005-12-13T12:04:33Z        500.0
#
#                 Activity        ...        Funded Date.hour  \
# 0           Butcher Shop        ...                     6.0
# 1  Food Production/Sales        ...                     6.0
#
#    Funded Date.minute Funded Date.second Paid Date.year Paid Date.month  \
# 0                27.0               55.0         2005.0            12.0
# 1                27.0               55.0         2005.0            12.0
#
#    Paid Date.day-of-month  Paid Date.day-of-week  Paid Date.hour  \
# 0                    13.0                    2.0            12.0
# ...

# %%
kiva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560816 entries, 0 to 560815
# Data columns (total 29 columns):
# id                          560816 non-null int64
# Funded Date                 541781 non-null object
# Funded Amount               560816 non-null int64
# Country                     560816 non-null object
# Country Code                560815 non-null object
# Local Currency              559003 non-null object
# Loan Amount                 560816 non-null int64
# Paid Date                   436155 non-null object
# Paid Amount                 527660 non-null float64
# Activity                    560816 non-null object
# Sector                      560816 non-null object
# Delinquent                  560816 non-null bool
# Name                        560728 non-null object
# Use                         560799 non-null object
# Status                      560812 non-null object
# Funded Date.year            541781 non-null float64
# ...

# %%
kiva.describe()
# Out:
#                   id  Funded Amount    Loan Amount    Paid Amount  \
# count  560816.000000  560816.000000  560816.000000  527660.000000
# mean   281299.662317     772.883932     805.584229     695.976417
# std    162367.695928     808.405587     820.984061     743.755347
# min        84.000000       0.000000       0.000000       0.000000
# 25%    140419.750000     300.000000     325.000000     250.000000
# 50%    281470.500000     550.000000     575.000000     500.000000
# 75%    421958.250000     975.000000    1000.000000     875.000000
# max    562429.000000   49525.000000   49525.000000   17650.000000
#
#        Funded Date.year  Funded Date.month  Funded Date.day-of-month  \
# count     541781.000000      541781.000000             541781.000000
# mean        2010.458916           6.527534                 16.710647
# std            1.680394           3.533762                  8.408576
# min         2005.000000           1.000000                  1.000000
# ...

# %%
kiva.describe(include=['O'])
# Out:
#                  Funded Date      Country Country Code Local Currency  \
# count                 541781       560816       560815         559003
# unique                486601           75           74             61
# top     2005-03-31T06:27:55Z  Philippines           PH            USD
# freq                     203        84997        84997         106203
#
#                    Paid Date       Activity  Sector       Name  \
# count                 436155         560816  560816     560728
# unique                247129            149      15     150071
# top     2008-04-24T03:04:05Z  General Store    Food  Anonymous
# freq                     183          44126  145477      28431
#
#                                             Use  Status
# count                                    560799  560812
# unique                                   379718       9
# top     To purchase additional products to sell    paid
# freq                                       2526  435949

# %%
#checking the missing data.
missing_data = kiva.isnull().sum().sort_values(ascending = True)
percent = (kiva.isnull().sum()/kiva.isnull().count()).sort_values(ascending = False)
missing_values = pd.concat([missing_data, percent],axis=1,keys=['Total Missing values', 'Percentage'])
missing_values
# Out:
#                           Total Missing values  Percentage
# Activity                                     0    0.000000
# Country                                      0    0.000000
# Country Code                                 1    0.000002
# Delinquent                                   0    0.000000
# Funded Amount                                0    0.000000
# Funded Date                              19035    0.033942
# Funded Date.day-of-month                 19035    0.033942
# Funded Date.day-of-week                  19035    0.033942
# Funded Date.hour                         19035    0.033942
# Funded Date.minute                       19035    0.033942
# Funded Date.month                        19035    0.033942
# Funded Date.second                       19035    0.033942
# Funded Date.year                         19035    0.033942
# Loan Amount                                  0    0.000000
# Local Currency                            1813    0.003233
# ...

# %%
#sector-wise analysis
sector_count = kiva['Sector'].value_counts()
sns.barplot(y=sector_count.index, x = sector_count.values)
for i, j in enumerate(sector_count.values):
    plt.text(1, i, j, color='k', fontsize=12)
plt.xlabel("Number of Loans")
plt.ylabel("Sectors")
plt.title("Number of Loans made in different Sectors")
# Out:
# Text(0.5,1,'Number of Loans made in different Sectors')

# %%
#Status of the loan
status_count = kiva['Status'].value_counts()
sns.barplot(status_count.values, status_count.index)
for i, j in enumerate(status_count.values):
    plt.text(5000, i, j, color='k', fontsize=12)
plt.xlabel("Count of the Status")
plt.ylabel("Loan Status")
plt.title("Loan Status of differnt Loans")
# Out:
# Text(0.5,1,'Loan Status of differnt Loans')

# %%
kiva['Status'].value_counts().plot(kind='pie', figsize=(10,10)) #Not very informative

# %%
#Count of Activity for which Loan was asked
activity_count = kiva['Activity'].value_counts().head(12)
sns.barplot(activity_count.values, activity_count.index)
for i, j in enumerate(activity_count.values):
    plt.text(1, i, j, color='k', fontsize=12)
plt.xlabel("Count of the activity")
plt.ylabel("Activity")
plt.title("Count of Top 12 Activity");

# %%
#Count of loan recieved by each country
country_count = kiva['Country'].value_counts().head(12)
sns.barplot(country_count.values, country_count.index)
for i, j in enumerate(country_count.values):
    plt.text(1, i, j, color='k', fontsize=12)
plt.xlabel("Count of the Loan")
plt.ylabel("Country")
plt.title("Top 12 Country to recieve Loan")
# Out:
# Text(0.5,1,'Top 12 Country to recieve Loan')

# %%
#Distribution of Funded Amount
plt.figure(figsize = (12, 8))
sns.distplot(kiva['Funded Amount'])
plt.xlim(0,5000)
# Out:
# c:\python\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (0, 5000)

# %%
plt.figure(figsize = (12,8))
plt.scatter(range(kiva.shape[0]), np.sort(kiva['Funded Amount'].values))
plt.xlabel("Count")
plt.ylabel("Funded Amount")
plt.title("Distribution of Funded Amount");

# %%
#Distribution of Loan Amount
sns.distplot(kiva['Loan Amount'])
# Out:
# c:\python\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Distribution of Loan Amount
plt.scatter(range(kiva.shape[0]), np.sort(kiva['Loan Amount'].values))
plt.xlabel("Count")
plt.ylabel("Loan Amount")
plt.title("Distribution of Loan Amount");

# %%
#Distribution of Sectors
import squarify
plt.figure(figsize=(15,12))
squarify.plot(sector_count.values, label=sector_count.index, value=sector_count.values)
plt.title("Distribution of Sectors");

# %%
#Use of the Loans
use_count = kiva['Use'].value_counts().head(12)
sns.barplot(use_count.values, use_count.index)
for i, j in enumerate(use_count.values):
    plt.text(1, i, j, color='k', fontsize=12)
plt.xlabel("Count of the Loans")
plt.ylabel("Different Uses of Loan");
